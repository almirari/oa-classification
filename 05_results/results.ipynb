# %%
# %run "D:/UNI/TUGAS-AKHIR/code/oa-classification/05_results/eval_baseline.py"
# Out:
# ...
#   01_baseline — Standalone Model Evaluation (CE / CORAL / CORN / Niu)
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\oa-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\oa-classification\05_results
#   Device       : cpu
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test dir     : D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test samples : 1656
#   Classes (folder → idx): {'0': 0, '1': 1, '2': 2, '3': 3, '4': 4}
#
#
# ...
#   Baseline — MobileNetV3-Small (Cross-Entropy)
# ...
#
#   Seed 33 — s1_seed33_best.pth
#   Training best val QWK: 0.7746
#   Evaluating ...
#     batch 52/52
#   QWK=0.7993 | Acc=63.22% | MAE=0.4336 | RMSE=0.7550
#
#   Seed 81 — s1_seed81_best.pth
#   Training best val QWK: 0.7885
#   Evaluating ...
#     batch 52/52
#   QWK=0.7945 | Acc=61.11% | MAE=0.4523 | RMSE=0.7634
#
#   Seed 5 — s1_seed5_best.pth
#   Training best val QWK: 0.7700
#   Evaluating ...
#     batch 52/52
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/oa-classification/05_results/eval_singlekd.py"
# Out:
# ...
#   03_kd_single — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\oa-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\oa-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test dir     : D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test samples : 1656
#   Classes (folder → idx): {'0': 0, '1': 1, '2': 2, '3': 3, '4': 4}
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Single-Teacher KD — CE  (ResNet-50-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.7807
#   Evaluating ...
#     batch 52/52
#   QWK=0.7981 | Acc=63.10% | MAE=0.4378 | RMSE=0.7602
#
#   Seed 81 — seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.7653
#   Evaluating ...
# ...

# %%
# %run "D:/UNI/TUGAS-AKHIR/code/oa-classification/05_results/eval_multikd.py"
# Out:
# ...
#   04_kd_multi — Student + Teacher Evaluation
# ...
#   Project root : D:\UNI\TUGAS-AKHIR\code\oa-classification
#   Results dir  : D:\UNI\TUGAS-AKHIR\code\oa-classification\05_results
#
# [Dataset]
#   Dataset already extracted → D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test dir     : D:\UNI\TUGAS-AKHIR\code\oa-classification\_dataset_extracted\test
#   Test samples : 1656
#   Classes (folder → idx): {'0': 0, '1': 1, '2': 2, '3': 3, '4': 4}
#
#
# ############################################################################
#   STUDENT MODELS
# ############################################################################
#
#
# ...
#   Multi-Teacher KD — CE  (ResNet-50-CE + EffNetB3-CE → MobileNetV3-Small)
# ...
#
#   Seed 33 — kd_seed33_best.pth
#   Head : CE  |  Training best val QWK: 0.8069
#   Evaluating ...
#     batch 52/52
#   QWK=0.8226 | Acc=63.22% | MAE=0.4022 | RMSE=0.6872
#
#   Seed 81 — kd_seed81_best.pth
#   Head : CE  |  Training best val QWK: 0.8118
# ...
